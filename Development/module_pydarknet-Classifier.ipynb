# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pydarknet

# %%
from pydarknet.libdarknet.structs import Image

# %%
classifier = pydarknet.Classifier("cfg/coco.data", "cfg/yolov3.cfg", "weights/yolov3.weights")
classifier
# Out:
# Classifier<cfg/coco.data, cfg/yolov3.cfg, weights/yolov3.weights>

# %%
img = classifier.detect(classifier.root+"/data/dog.jpg")
# Out:
# Loading network......Done
# Loading metadata......Done

# %%
img
# Out:
# [Classified<dog, (134.83998107910156, 214.18678283691406, 313.66184997558594, 542.5165863037109)>,
#  Classified<truck, (476.8968048095703, 81.5092544555664, 684.7720184326172, 168.59276580810547)>,
#  Classified<bicycle, (99.2535400390625, 124.20358276367188, 589.5813598632812, 447.6205139160156)>]

# %%
img[0].image
# Out:
# <PIL.Image.Image image mode=RGB size=179x329 at 0x7F55F80D85F8>

# %%
img[1].image
# Out:
# <PIL.Image.Image image mode=RGB size=208x87 at 0x7F55F8052470>

# %%
img[2].image
# Out:
# <PIL.Image.Image image mode=RGB size=491x324 at 0x7F55F80549B0>

# %%
from scipy.misc import imread

# %%
np.i

# %%
imag

# %%
results = list()
for image in glob.glob(classifier.root + "/data/*.jpg"):
    ret = classifier.detect(image)
    results.append(ret)
