# %% [markdown]
# # Batch```pydarknet``` detection example.

# %%
import sys
import pydarknet
import numpy as np

# %%
# Load a classifier.
classifier = pydarknet.Classifier("cfg/coco.data", "cfg/yolov3.cfg", "weights/yolov3.weights")
classifier
# Out:
# Classifier<cfg/coco.data, cfg/yolov3.cfg, weights/yolov3.weights>

# %%
import glob

# %%
images = glob.glob(classifier.root+"/data/*.jpg")

# %%
import IPython.display

# %%
for image in images:
    dets = classifier.detect(image)
    for det in dets:
        print(det.classification)
        IPython.display.display(det.crop)
# Out:
# Loading network......Done
# Loading metadata......Done
# giraffe
# <PIL.Image.Image image mode=RGB size=275x389 at 0x7F1F0296AEF0>
# zebra
# <PIL.Image.Image image mode=RGB size=170x232 at 0x7F1ED00CC048>
# kite
# <PIL.Image.Image image mode=RGB size=75x71 at 0x7F1EF08BD240>
# kite
# <PIL.Image.Image image mode=RGB size=22x31 at 0x7F1ED00CC0F0>
# kite
# <PIL.Image.Image image mode=RGB size=16x29 at 0x7F1F029658D0>
# kite
# <PIL.Image.Image image mode=RGB size=21x20 at 0x7F1F0296A240>
# person
# <PIL.Image.Image image mode=RGB size=55x151 at 0x7F1F0296AE10>
# person
# <PIL.Image.Image image mode=RGB size=60x163 at 0x7F1F0296AD68>
# person
# <PIL.Image.Image image mode=RGB size=25x57 at 0x7F1EAAF8AAC8>
# person
# <PIL.Image.Image image mode=RGB size=14x22 at 0x7F1F0296AEF0>
# person
# <PIL.Image.Image image mode=RGB size=8x16 at 0x7F1EAAF8ACF8>
# person
# <PIL.Image.Image image mode=RGB size=17x17 at 0x7F1EAAF8ACC0>
# person
# <PIL.Image.Image image mode=RGB size=16x34 at 0x7F1EAAF8AC50>
# person
# <PIL.Image.Image image mode=RGB size=22x57 at 0x7F1EAAF8AE48>
# person
# <PIL.Image.Image image mode=RGB size=15x27 at 0x7F1EAAF8AEF0>
# horse
# <PIL.Image.Image image mode=RGB size=192x224 at 0x7F1EF08B0160>
# dog
# <PIL.Image.Image image mode=RGB size=142x84 at 0x7F1F029651D0>
# person
# <PIL.Image.Image image mode=RGB size=82x275 at 0x7F1F0296AE10>
# bird
# <PIL.Image.Image image mode=RGB size=466x329 at 0x7F1F029651D0>
